# %% [markdown]
# # Linear Regression

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. 線性迴歸基本概念

# %% [markdown]
# #### 直線
#
# $$f(x) = 1.2x + 0.8$$

# %%
#準備 50 個點
#5-0/50 = 0.1 +....
# 0~5線性切割
x = np.linspace(0, 5, 50)
print(x)
# Out:
# [0.         0.10204082 0.20408163 0.30612245 0.40816327 0.51020408
#  0.6122449  0.71428571 0.81632653 0.91836735 1.02040816 1.12244898
#  1.2244898  1.32653061 1.42857143 1.53061224 1.63265306 1.73469388
#  1.83673469 1.93877551 2.04081633 2.14285714 2.24489796 2.34693878
#  2.44897959 2.55102041 2.65306122 2.75510204 2.85714286 2.95918367
#  3.06122449 3.16326531 3.26530612 3.36734694 3.46938776 3.57142857
#  3.67346939 3.7755102  3.87755102 3.97959184 4.08163265 4.18367347
#  4.28571429 4.3877551  4.48979592 4.59183673 4.69387755 4.79591837
#  4.89795918 5.        ]

# %%
y = 1.2*x + 0.8
y
# Out:
# array([0.8       , 0.92244898, 1.04489796, 1.16734694, 1.28979592,
#        1.4122449 , 1.53469388, 1.65714286, 1.77959184, 1.90204082,
#        2.0244898 , 2.14693878, 2.26938776, 2.39183673, 2.51428571,
#        2.63673469, 2.75918367, 2.88163265, 3.00408163, 3.12653061,
#        3.24897959, 3.37142857, 3.49387755, 3.61632653, 3.73877551,
#        3.86122449, 3.98367347, 4.10612245, 4.22857143, 4.35102041,
#        4.47346939, 4.59591837, 4.71836735, 4.84081633, 4.96326531,
#        5.08571429, 5.20816327, 5.33061224, 5.45306122, 5.5755102 ,
#        5.69795918, 5.82040816, 5.94285714, 6.06530612, 6.1877551 ,
#        6.31020408, 6.43265306, 6.55510204, 6.67755102, 6.8       ])

# %%
#畫圖
plt.scatter(x,y)
plt.plot(x, 1.2*x+0.8, 'r')

# %% [markdown]
# #### add noise
#
# $$f(x) + \varepsilon(x)$$

# %%
y = 1.2*x + 0.8 + 0.6*np.random.randn(50)
print(y)
# Out:
# [0.324886   0.90313245 1.32930379 0.5385804  1.12640371 1.36003093
#  2.41174455 2.13814023 2.13154549 1.46540578 2.83772244 1.81410396
#  1.61863794 2.63837147 2.10388893 2.75586145 2.92421352 3.76161343
#  2.85439809 3.42203242 4.06258411 3.88775291 3.62312712 4.51951107
#  3.52490431 3.69388046 2.88945182 4.15494682 3.64909823 4.33550645
#  4.35405063 3.90138235 5.45512452 4.9699165  5.08954847 5.58780085
#  5.42199029 4.85274645 5.59046378 5.82882138 5.82410559 5.04768601
#  6.71500852 5.41629232 5.43979554 6.89290644 6.86400679 7.51762556
#  7.27447399 6.75601416]

# %%
plt.scatter(x,y)
plt.plot(x, 1.2*x + 0.8, 'r')

# %%
from sklearn.linear_model import LinearRegression
regr = LinearRegression()

# %%
regr
# Out:
# LinearRegression()

# %% [markdown]
# 要求資料轉換<br>
#
# $$[x_1, x_2, \ldots, x_{50}]$$
#
# ==>
#
# $$[[x_1], [x_2], \ldots, [x_{50}]]$$
#
#
# 矩陣的概念

# %%
print(x.shape)
X = x.reshape(-1,1)
X.shape
# Out:
# (50,)
# (50, 1)

# %%
regr.fit(X,y)
# Out:
# LinearRegression()

# %%
Y = regr.predict(X)
print(Y)
# Out:
# [0.81654901 0.94126173 1.06597446 1.19068719 1.31539991 1.44011264
#  1.56482537 1.68953809 1.81425082 1.93896355 2.06367627 2.188389
#  2.31310173 2.43781445 2.56252718 2.68723991 2.81195263 2.93666536
#  3.06137809 3.18609081 3.31080354 3.43551626 3.56022899 3.68494172
#  3.80965444 3.93436717 4.0590799  4.18379262 4.30850535 4.43321808
#  4.5579308  4.68264353 4.80735626 4.93206898 5.05678171 5.18149444
#  5.30620716 5.43091989 5.55563262 5.68034534 5.80505807 5.9297708
#  6.05448352 6.17919625 6.30390897 6.4286217  6.55333443 6.67804715
#  6.80275988 6.92747261]

# %%
#了解你的訓練參數
regr.get_params()
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}

# %%
plt.scatter(x, y) #原本 
plt.plot(x, Y, 'ro') #預測
#calculate mse
mse = np.sum((Y-y)**2) / len(y)
print(mse)
# Out:
# 0.26273010856657664

# %%
#Y=WX+b
W=regr.coef_#斜率
W
# Out:
# array([1.22218472])

# %%
b=regr.intercept_ #截距
b
# Out:
# 0.8165490079202695

# %%
Y
# Out:
# array([0.81654901, 0.94126173, 1.06597446, 1.19068719, 1.31539991,
#        1.44011264, 1.56482537, 1.68953809, 1.81425082, 1.93896355,
#        2.06367627, 2.188389  , 2.31310173, 2.43781445, 2.56252718,
#        2.68723991, 2.81195263, 2.93666536, 3.06137809, 3.18609081,
#        3.31080354, 3.43551626, 3.56022899, 3.68494172, 3.80965444,
#        3.93436717, 4.0590799 , 4.18379262, 4.30850535, 4.43321808,
#        4.5579308 , 4.68264353, 4.80735626, 4.93206898, 5.05678171,
#        5.18149444, 5.30620716, 5.43091989, 5.55563262, 5.68034534,
#        5.80505807, 5.9297708 , 6.05448352, 6.17919625, 6.30390897,
#        6.4286217 , 6.55333443, 6.67804715, 6.80275988, 6.92747261])

# %%
#可以將新的x資料帶入算出結果
W*3+b
# Out:
# array([4.48310317])

# %%
y
# Out:
# array([ 0.27525339,  1.33994008,  0.91197999, -0.20320858,  1.89085355,
#         0.60847933,  1.48341042,  0.93030304,  1.35044448,  2.53660118,
#         3.19097507,  1.59325492,  3.29520382,  2.39603642,  2.42674534,
#         3.32204164,  2.85852214,  2.90697684,  2.52972766,  3.11008526,
#         2.90785658,  3.85680041,  3.44705739,  3.42994352,  2.59456672,
#         3.79364206,  4.66116825,  3.79851919,  4.45159162,  4.30879935,
#         4.91409624,  4.70701615,  6.28523753,  4.07812527,  5.17605873,
#         4.62142594,  4.77138525,  4.78797527,  6.15181021,  4.81071081,
#         5.84798456,  5.19384327,  6.18938522,  5.53159052,  6.32867975,
#         5.78822922,  7.0023755 ,  7.53394173,  6.22492988,  5.53340938])
